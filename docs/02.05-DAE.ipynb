# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains material from [CBE60499](https://ndcbe.github.io/CBE60499);
# content is available [on Github](git@github.com:ndcbe/CBE60499.git).*

# %% [markdown]
# <!--NAVIGATION-->
# < [2.4 Generalized Disjunctive Programs](https://ndcbe.github.io/CBE60499/02.04-GDP.html) | [Contents](toc.html) | [2.6 Stochastic Programming](https://ndcbe.github.io/CBE60499/02.06-SP.html) ><p><a href="https://colab.research.google.com/github/ndcbe/CBE60499/blob/master/docs/02.05-DAE.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://ndcbe.github.io/CBE60499/02.05-DAE.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>

# %% [markdown]
# # 2.5 Dynamic Optimization

# %% [markdown]
# ## 2.5.1 Differential Algebriac Equations

# %% [markdown]
# <!--NAVIGATION-->
# < [2.4 Generalized Disjunctive Programs](https://ndcbe.github.io/CBE60499/02.04-GDP.html) | [Contents](toc.html) | [2.6 Stochastic Programming](https://ndcbe.github.io/CBE60499/02.06-SP.html) ><p><a href="https://colab.research.google.com/github/ndcbe/CBE60499/blob/master/docs/02.05-DAE.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://ndcbe.github.io/CBE60499/02.05-DAE.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>
