# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains material from [CBE60499](https://ndcbe.github.io/CBE60499);
# content is available [on Github](git@github.com:ndcbe/CBE60499.git).*

# %% [markdown]
# <!--NAVIGATION-->
# < [2.12 Pyomo Homework 3](https://ndcbe.github.io/CBE60499/02.12-Pyomo3.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [3.1 Linear Algebra Review and SciPy Basics](https://ndcbe.github.io/CBE60499/03.01-Math-Primer.html) ><p><a href="https://colab.research.google.com/github/ndcbe/CBE60499/blob/master/docs/03.00-Unconstrained.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://ndcbe.github.io/CBE60499/03.00-Unconstrained.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>

# %% [markdown]
# # 3.0 Unconstrained Nonlinear Optimization: Theory and Algorithms

# %% [markdown]
# <!--NAVIGATION-->
# < [2.12 Pyomo Homework 3](https://ndcbe.github.io/CBE60499/02.12-Pyomo3.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [3.1 Linear Algebra Review and SciPy Basics](https://ndcbe.github.io/CBE60499/03.01-Math-Primer.html) ><p><a href="https://colab.research.google.com/github/ndcbe/CBE60499/blob/master/docs/03.00-Unconstrained.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://ndcbe.github.io/CBE60499/03.00-Unconstrained.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>
