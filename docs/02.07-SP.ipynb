# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains material from [CBE60499](https://ndcbe.github.io/CBE60499);
# content is available [on Github](git@github.com:ndcbe/CBE60499.git).*

# %% [markdown]
# <!--NAVIGATION-->
# < [2.6 Dynamic Optimization with Pyomo.DAE](https://ndcbe.github.io/CBE60499/02.06-Pyomo-DAE.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [2.8 Parameter estimation with parmest](https://ndcbe.github.io/CBE60499/02.08-Parmest-tutorial.html) ><p><a href="https://colab.research.google.com/github/ndcbe/CBE60499/blob/master/docs/02.07-SP.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://ndcbe.github.io/CBE60499/02.07-SP.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>

# %% [markdown]
# # 2.7 Stochastic Programming

# %% [markdown]
# ## 2.7.1 Key Concepts

# %% [markdown]
# ### 2.7.1.1 Infinite Dimensional Formulation

# %% [markdown]
# ### 2.7.1.2 Discrete (Finite Dimensional) Approximations

# %% [markdown]
# ### 2.7.1.3 Sample Average Approximation

# %% [markdown]
# ### 2.7.1.4 Sparse Grids (Worst Case)

# %% [markdown]
# ## 2.7.2 Farmers Example

# %% [markdown]
# https://mpi-sppy.readthedocs.io/en/latest/quick_start.html
#
# https://mpi-sppy.readthedocs.io/en/latest/examples.html#examples

# %% [markdown]
# ## 2.7.3 PID Controller Tuning Example

# %% [markdown]
# <!--NAVIGATION-->
# < [2.6 Dynamic Optimization with Pyomo.DAE](https://ndcbe.github.io/CBE60499/02.06-Pyomo-DAE.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [2.8 Parameter estimation with parmest](https://ndcbe.github.io/CBE60499/02.08-Parmest-tutorial.html) ><p><a href="https://colab.research.google.com/github/ndcbe/CBE60499/blob/master/docs/02.07-SP.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://ndcbe.github.io/CBE60499/02.07-SP.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>
